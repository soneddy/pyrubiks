# %%
# %pylab inline
from pyrubiks import cube
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
seed(0)
test = cube(size=2)
test.display()

# %%
test.clockwise('bottom')
test.cntclkwise()
test.clockwise('right')
test.cntclkwise()
test.cntclkwise('right')
test.display()

# %%
test.cntclkwise('back')
test.cntclkwise('left')
test.cntclkwise('front')
test.clockwise('left')
test.clockwise('back')
test.cntclkwise('left')
test.clockwise('front')
test.clockwise('left')
test.display()

# %%
test.cntclkwise('back')
test.cntclkwise('left')
test.cntclkwise('front')
test.clockwise('left')
test.clockwise('back')
test.cntclkwise('left')
test.clockwise('front')
test.clockwise('left')
test.display()

# %%
test.clockwise('bottom')
test.display()
